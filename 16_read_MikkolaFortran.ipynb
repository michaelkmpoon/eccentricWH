# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import time
import rebound
import matplotlib.pyplot as plt
import numpy as np
import integrator_tools

# %matplotlib inline

# configuring plots
#plt.rc('text', usetex=True)            # use LaTeX for text
plt.rc('font', family='serif')          # use serif font
plt.rcParams.update({'font.size': 14})  # increase font size

# %%
output = np.loadtxt('R3B/output')

# %%
n_time_idx = np.shape(output)[0]

# %%
n_time_idx
# Out:
# 1332

# %%
plt.figure(figsize=(10,8))
plt.plot(output[:n_time_idx,1],output[:n_time_idx,2], label='1st planet', c='tab:green')
plt.plot(output[:n_time_idx,4],output[:n_time_idx,5], label='2nd planet', c='tab:blue')
plt.scatter(output[:n_time_idx,7],output[:n_time_idx,8], label='Sun', c='tab:red')
plt.xlim(-50,50)
plt.ylim(-10,90)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,4.5))
plt.plot(output[:100,1],output[:100,2], label='2nd planet', c='tab:green')
plt.plot(output[:100,4],output[:100,5], label='1st planet', c='tab:blue')
plt.scatter(output[:100,7],output[:100,8], label='Sun', c='tab:red')
plt.legend()
plt.show()

# %%
len(output[:,0])
# Out:
# 11597
